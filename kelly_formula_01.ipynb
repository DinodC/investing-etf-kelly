# %% [markdown]
# # Kelly Formula

# %% [markdown]
# ## How To Find The Optimal Capital Allocation Using The Kelly Formula

# %% [markdown]
# ## Introduction
# ...

# %% [markdown]
# ## Exchange Traded Fund (ETF)
# ...

# %% [markdown]
# ## Vanguard
# ...
#
#
# ### Jack Bogle
# ...
#
#
# ### Vanguard ETFs
# ...

# %% [markdown]
# ## Retrieve Vanguard ETFs Data
# 1. Source Vanguard ETFs list of tickers.
# 2. Source Vanguard ETFs historical OHLCV data.

# %% [markdown]
# ## Source Vanguard ETFs List Of Tickers

# %% [markdown]
# Import packages

# %%
import pandas as pd

# %%
from pandas import Series, DataFrame

# %%
from selenium import webdriver

# %% [markdown]
# Create a new instance of Google Chrome

# %%
driver = webdriver.Chrome('/Applications/chromedriver')

# %% [markdown]
# Open the Vanguard website containing the ETF list

# %%
driver.get('https://investor.vanguard.com/etf/list')

# %% [markdown]
# Inspecting the page, we notice that the information is stored in a table, and each entry is in a tr with class name equal to "productEntry". We use find_elements_by_class_name to get the list of ETFs.

# %%
content = driver.find_elements_by_class_name('productEntry')

# %% [markdown]
# Count the number of elements in content

# %%
len(content)
# Out:
# 118

# %% [markdown]
# Inspect the content

# %%
for i in content:
    print(i.text)
# Out:
# Total Corporate Bond ETF
# Vanguard Select Funds
# Tax-Exempt Bond ETF
# Dividend Appreciation ETF
# ESG U.S. Stock ETF
# Growth ETF
# High Dividend Yield ETF
# Large-Cap ETF
# Mega Cap ETF
# Mega Cap Growth ETF
# Mega Cap Value ETF
# Vanguard Select Funds
# S&P 500 ETF
# Vanguard Select Funds
# Total Stock Market ETF
# Value ETF
# Vanguard Select Funds
# Extended Market ETF
# Mid-Cap ETF
# Mid-Cap Growth ETF
# Mid-Cap Value ETF
# Small-Cap ETF
# Small-Cap Growth ETF
# Small-Cap Value ETF
# Total World Bond ETF
# Vanguard Select Funds
# Total International Bond ETF
# Emerging Markets Government Bond ETF
# Total World Stock ETF
# ESG International Stock ETF
# FTSE All-World ex-US ETF
# FTSE All-World ex-US Small-Cap ETF
# Vanguard Select Funds
# FTSE Developed Markets ETF
# FTSE Europe ETF
# FTSE Pacific ETF
# Global ex-U.S. Real Estate ETF
# International Dividend Appreciation ETF
# International High Dividend Yield ETF
# Vanguard Select Funds
# Total International Stock ETF
# Vanguard Select Funds
# FTSE Emerging Markets ETF
# Communication Services ETF
# Consumer Discretionary ETF
# Consumer Staples ETF
# Energy ETF
# Financials ETF
# Health Care ETF
# Industrials ETF
# Information Technology ETF
# Materials ETF
# Real Estate ETF
# Utilities ETF
# EDV Bond - Long-term Government 0.07% $125.90 -$2.02
# decreased
# -1.58%
# decreased
# 2.64%A
# 30 day
# 6/3/2019 11.80% 14.61% 7.58% 8.82% 8.04% (12/06/2007)
# BIV Bond - Inter-term Investment 0.07% $85.35 -$0.14
# decreased
# -0.16%
# decreased
# 2.74%A
# 30 day
# 6/3/2019 6.29% 8.34% 3.13% 4.97% 5.07% (04/03/2007)
# VGIT Bond - Inter-term Government 0.07% $65.44 -$0.15
# decreased
# -0.22%
# decreased
# 2.18%A
# 30 day
# 6/3/2019 4.12% 6.75% 2.21% — 2.95% (11/19/2009)
# BLV Bond - Long-term Investment 0.07% $94.48 -$0.49
# decreased
# -0.52%
# decreased
# 3.54%A
# 30 day
# 6/3/2019 9.74% 10.28% 5.13% 7.55% 6.86% (04/03/2007)
# VGLT Bond - Long-term Government 0.07% $80.46 -$0.89
# decreased
# -1.09%
# decreased
# 2.63%A
# 30 day
# 6/3/2019 8.95% 11.83% 5.40% — 6.32% (11/19/2009)
# VMBS Bond - Inter-term Government 0.07% $52.56 -$0.04
# decreased
# -0.08%
# decreased
# 2.89%J
# 30 day
# 6/3/2019 3.36% 5.16% 2.29% — 2.80% (11/19/2009)
# BSV Bond - Short-term Investment 0.07% $80.14 -$0.04
# decreased
# -0.05%
# decreased
# 2.34%A
# 30 day
# 6/3/2019 2.97% 4.59% 1.58% 2.02% 2.77% (04/03/2007)
# VTIP Bond - Short-term Government 0.06% $49.26 $0.01
# increased
# 0.02%
# increased
# 0.40%G,E
# 30 day
# 5/30/2019 2.80% 2.76% 0.79% — 0.66% (10/12/2012)
# VGSH Bond - Short-term Government 0.07% $60.72 -$0.04
# decreased
# -0.07%
# decreased
# 2.20%A
# 30 day
# 6/3/2019 2.01% 3.45% 1.05% — 0.99% (11/19/2009)
# BND Bond - Inter-term Investment 0.035% $82.13 -$0.13
# decreased
# -0.16%
# decreased
# 2.78%A
# 30 day
# 6/3/2019 4.93% 6.56% 2.65% 3.68% 4.08% (04/03/2007)
# VCIT Bond - Inter-term Investment 0.07% $88.06 $0.04
# increased
# 0.05%
# increased
# 3.48%A
# 30 day
# 6/3/2019 7.90% 8.76% 3.73% — 5.46% (11/19/2009)
# VCLT Bond - Long-term Investment 0.07% $92.94 -$0.21
# decreased
# -0.23%
# decreased
# 4.28%A
# 30 day
# 6/3/2019 11.02% 9.65% 5.06% — 7.16% (11/19/2009)
# VCSH Bond - Short-term Investment 0.07% $80.05 -$0.05
# decreased
# -0.06%
# decreased
# 2.89%A
# 30 day
# 6/3/2019 3.94% 5.28% 2.21% — 2.98% (11/19/2009)
# VTC Bond - Inter-term Investment 0.07% $84.71 -$0.07
# decreased
# -0.08%
# decreased
# 3.27%B
# 30 day
# 6/3/2019 7.45% 7.59% — — 3.22% (11/07/2017)
# VTEB Bond - Long-term National Muni 0.08% $52.91 -$0.02
# decreased
# -0.04%
# decreased
# 2.04%A
# 30 day
# 6/3/2019 4.66% 6.31% — — 3.51% (08/21/2015)
# VIG Stock - Large-Cap Blend 0.06% $110.72 $2.01
# increased
# 1.85%
# increased
# 1.97%B
# 30 day
# 5/31/2019 13.65% 8.66% 9.32% 12.97% 8.29% (04/21/2006)
# ESGV Stock - Large-Cap Blend 0.12% $48.84 $1.12
# increased
# 2.35%
# increased
# 1.74%B
# 30 day
# 5/31/2019 13.95% — — — -3.52% (09/18/2018)
# VUG Stock - Large-Cap Growth 0.04% $154.77 $3.73
# increased
# 2.47%
# increased
# 1.23%B
# 30 day
# 5/31/2019 15.65% 4.63% 11.06% 15.07% 8.81% (01/26/2004)
# VYM Stock - Large-Cap Value 0.06% $84.98 $1.58
# increased
# 1.89%
# increased
# 3.50%B
# 30 day
# 5/31/2019 9.89% 1.63% 8.03% 13.36% 7.28% (11/10/2006)
# VV Stock - Large-Cap Blend 0.04% $128.89 $2.84
# increased
# 2.25%
# increased
# 2.01%B
# 30 day
# 5/31/2019 12.96% 3.75% 9.55% 13.92% 8.32% (01/27/2004)
# MGC Stock - Large-Cap Blend 0.07% $96.89 $2.14
# increased
# 2.25%
# increased
# 2.06%B
# 30 day
# 5/31/2019 12.20% 4.23% 9.86% 13.81% 8.10% (12/17/2007)
# MGK Stock - Large-Cap Growth 0.07% $122.41 $2.95
# increased
# 2.47%
# increased
# 1.34%B
# 30 day
# 5/31/2019 14.60% 3.98% 11.45% 15.15% 9.69% (12/17/2007)
# MGV Stock - Large-Cap Value 0.07% $77.96 $1.54
# increased
# 2.02%
# increased
# 2.82%B
# 30 day
# 5/31/2019 10.09% 4.03% 8.42% 12.60% 6.59% (12/17/2007)
# VOO Stock - Large-Cap Blend 0.03% $257.68 $5.66
# increased
# 2.25%
# increased
# 2.07%B
# 30 day
# 5/31/2019 12.83% 3.75% 9.63% — 13.49% (09/07/2010)
# VTI Stock - Large-Cap Blend 0.03% $143.57 $3.24
# increased
# 2.31%
# increased
# 1.97%B
# 30 day
# 5/31/2019 13.16% 2.57% 9.25% 13.98% 6.88% (05/24/2001)
# VTV Stock - Large-Cap Value 0.04% $107.31 $2.11
# increased
# 2.01%
# increased
# 2.83%B
# 30 day
# 5/31/2019 10.43% 2.76% 8.18% 12.85% 7.66% (01/26/2004)
# VXF Stock - Mid-Cap Blend 0.07% $114.18 $2.90
# increased
# 2.61%
# increased
# 1.46%B
# 30 day
# 5/31/2019 14.77% -3.64% 7.33% 14.00% 9.09% (12/27/2001)
# VO Stock - Mid-Cap Blend 0.04% $160.45 $3.52
# increased
# 2.24%
# increased
# 1.62%B
# 30 day
# 5/31/2019 16.64% 1.63% 7.98% 14.37% 9.18% (01/26/2004)
# VOT Stock - Mid-Cap Growth 0.07% $143.08 $3.27
# increased
# 2.34%
# increased
# 0.85%B
# 30 day
# 5/31/2019 19.87% 6.34% 9.48% 14.64% 8.88% (08/17/2006)
# VOE Stock - Mid-Cap Value 0.07% $107.27 $2.30
# increased
# 2.19%
# increased
# 2.40%B
# 30 day
# 5/31/2019 13.22% -3.12% 6.43% 13.95% 7.86% (08/17/2006)
# VB Stock - Small-Cap Blend 0.05% $150.95 $3.77
# increased
# 2.56%
# increased
# 1.65%B
# 30 day
# 5/31/2019 14.83% -3.78% 7.30% 14.15% 8.71% (01/26/2004)
# VBK Stock - Small-Cap Growth 0.07% $177.37 $4.65
# increased
# 2.69%
# increased
# 0.80%B
# 30 day
# 5/31/2019 18.06% 0.63% 8.67% 14.89% 9.09% (01/26/2004)
# VBR Stock - Small-Cap Value 0.07% $127.21 $2.99
# increased
# 2.41%
# increased
# 2.36%B
# 30 day
# 5/31/2019 12.07% -7.52% 6.11% 13.33% 8.18% (01/26/2004)
# BNDW International 0.09% $77.75 -$0.05
# decreased
# -0.06%
# decreased
# 1.91%B
# 30 day
# 6/3/2019 4.79% — — — 6.12% (09/04/2018)
# BNDX International 0.09% $56.51 $0.05
# increased
# 0.09%
# increased
# 0.76%A
# 30 day
# 6/3/2019 4.67% 6.89% 4.09% — 4.05% (05/31/2013)
# VWOB International 0.30% $78.20 $0.41
# increased
# 0.52%
# increased
# 5.05%A
# 30 day
# 6/3/2019 6.99% 7.35% 3.97% — 4.26% (05/31/2013)
# VT International 0.09% $72.51 $1.23
# increased
# 1.73%
# increased
# — 11.26% -1.93% 5.45% 9.54% 5.55% (06/24/2008)
# VSGX International 0.15% $48.47 $0.45
# increased
# 0.94%
# increased
# — 9.17% — — — -4.05% (09/18/2018)
# VEU International 0.09% $49.51 $0.44
# increased
# 0.90%
# increased
# — 9.01% -6.26% 1.59% 5.90% 2.47% (03/02/2007)
# VSS International 0.12% $102.29 $1.14
# increased
# 1.13%
# increased
# — 8.07% -13.13% 1.15% 7.15% 9.61% (04/02/2009)
# VEA International 0.05% $40.51 $0.49
# increased
# 1.22%
# increased
# — 9.66% -7.04% 1.57% 6.33% 1.08% (07/20/2007)
# VGK International 0.09% $53.58 $0.67
# increased
# 1.27%
# increased
# — 10.86% -6.02% 0.26% 6.32% 4.01% (03/04/2005)
# VPL International 0.09% $64.26 $0.69
# increased
# 1.08%
# increased
# — 6.22% -9.98% 3.47% 6.35% 4.27% (03/04/2005)
# VNQI International 0.12% $58.05 $0.34
# increased
# 0.58%
# increased
# — 10.86% -0.60% 4.09% — 5.61% (11/01/2010)
# VIGI International 0.25% $65.48 $0.29
# increased
# 0.44%
# increased
# — 13.88% -0.63% — — 9.75% (02/25/2016)
# VYMI International 0.32% $60.21 $0.80
# increased
# 1.35%
# increased
# — 7.85% -4.25% — — 8.75% (02/25/2016)
# VXUS International 0.09% $51.23 $0.44
# increased
# 0.87%
# increased
# — 8.93% -6.98% 1.54% — 3.03% (01/26/2011)
# VWO International 0.12% $40.90 $0.03
# increased
# 0.07%
# increased
# — 7.45% -6.47% 1.91% 4.72% 5.92% (03/04/2005)
# VOX Stock - Sector 0.10% $83.12 $1.72
# increased
# 2.11%
# increased
# 1.07%B
# 30 day
# 5/31/2019 12.44% 2.94% 2.17% 8.89% 6.65% (09/23/2004)
# VCR Stock - Sector 0.10% $170.27 $4.65
# increased
# 2.80%
# increased
# 1.33%B
# 30 day
# 5/31/2019 13.45% 2.31% 10.96% 18.11% 9.44% (01/26/2004)
# VDC Stock - Sector 0.10% $145.75 $1.31
# increased
# 0.91%
# increased
# 2.77%B
# 30 day
# 5/31/2019 11.71% 13.12% 6.90% 12.32% 9.32% (01/26/2004)
# VDE Stock - Sector 0.10% $81.32 $1.48
# increased
# 1.85%
# increased
# 3.67%B
# 30 day
# 5/31/2019 6.25% -22.79% -7.86% 2.75% 5.18% (09/23/2004)
# VFH Stock - Sector 0.10% $67.44 $1.79
# increased
# 2.72%
# increased
# 2.35%B
# 30 day
# 5/31/2019 14.28% -3.53% 9.64% 12.42% 3.81% (01/26/2004)
# VHT Stock - Sector 0.10% $166.92 $3.08
# increased
# 1.88%
# increased
# 1.53%B
# 30 day
# 5/31/2019 4.69% 5.71% 10.06% 15.57% 9.43% (01/26/2004)
# VIS Stock - Sector 0.10% $139.59 $3.43
# increased
# 2.52%
# increased
# 1.73%B
# 30 day
# 5/31/2019 16.55% -1.58% 7.54% 14.44% 8.93% (09/23/2004)
# VGT Stock - Sector 0.10% $197.36 $6.50
# increased
# 3.40%
# increased
# 1.34%B
# 30 day
# 5/31/2019 18.71% 7.61% 17.18% 18.10% 10.10% (01/26/2004)
# VAW Stock - Sector 0.10% $122.16 $3.66
# increased
# 3.09%
# increased
# 2.13%B
# 30 day
# 5/31/2019 10.76% -11.39% 3.11% 9.92% 7.70% (01/26/2004)
# VNQ Stock - Sector 0.12% $86.79 -$0.32
# decreased
# -0.37%
# decreased
# note 17.18% 14.91% 7.58% 14.92% 8.72% (09/23/2004)
# VPU Stock - Sector 0.10% $131.12 $0.20
# increased
# 0.15%
# increased
# 3.21%B
# 30 day
# 5/31/2019 12.12% 17.11% 10.36% 12.69% 10.07% (01/26/2004)

# %% [markdown]
# We notice the following structure:
# 1. Elements 0-58 are the names of the ETFs.
# 2. Elements 59-118 are the tickers, asset class, etc. of the ETFs.

# %% [markdown]
# Create list for ETF names and tickers

# %%
# Initialize
etf_names = []
etf_tickers = []

for i in range(0, 59):
    # Get the names
    try:
        etf_names.append(content[i].text.split('\n')[1])
    except IndexError:
        etf_names.append(content[i].text)
    
    # Get the tickers
    etf_tickers.append(content[i + 59].text.split()[0])

# %% [markdown]
# Create Vanguard ETF DataFrame

# %%
etf_vanguard = pd.DataFrame({'Name': etf_names,
                             'Ticker': etf_tickers})

# %% [markdown]
# ### US Bond ETFs

# %%
etf_vanguard_us_bonds = etf_vanguard.iloc[0:15]

# %%
etf_vanguard_us_bonds
# Out:
#                                              Name Ticker
# 0                  Extended Duration Treasury ETF    EDV
# 1                      Intermediate-Term Bond ETF    BIV
# 2                  Intermediate-Term Treasury ETF   VGIT
# 3                              Long-Term Bond ETF    BLV
# 4                          Long-Term Treasury ETF   VGLT
# 5                  Mortgage-Backed Securities ETF   VMBS
# 6                             Short-Term Bond ETF    BSV
# 7   Short-Term Inflation-Protected Securities ETF   VTIP
# 8                         Short-Term Treasury ETF   VGSH
# 9                           Total Bond Market ETF    BND
# 10           Intermediate-Term Corporate Bond ETF   VCIT
# 11                   Long-Term Corporate Bond ETF   VCLT
# 12                  Short-Term Corporate Bond ETF   VCSH
# 13                       Total Corporate Bond ETF    VTC
# 14                            Tax-Exempt Bond ETF   VTEB

# %% [markdown]
# ### US Stock ETFs

# %%
etf_vanguard_us_stocks = etf_vanguard.iloc[15:33]

# %%
etf_vanguard_us_stocks.reset_index(inplace=True, drop=True)

# %%
etf_vanguard_us_stocks
# Out:
#                          Name Ticker
# 0   Dividend Appreciation ETF    VIG
# 1          ESG U.S. Stock ETF   ESGV
# 2                  Growth ETF    VUG
# 3     High Dividend Yield ETF    VYM
# 4               Large-Cap ETF     VV
# 5                Mega Cap ETF    MGC
# 6         Mega Cap Growth ETF    MGK
# 7          Mega Cap Value ETF    MGV
# 8                 S&P 500 ETF    VOO
# 9      Total Stock Market ETF    VTI
# 10                  Value ETF    VTV
# 11        Extended Market ETF    VXF
# 12                Mid-Cap ETF     VO
# 13         Mid-Cap Growth ETF    VOT
# 14          Mid-Cap Value ETF    VOE
# 15              Small-Cap ETF     VB
# 16       Small-Cap Growth ETF    VBK
# 17        Small-Cap Value ETF    VBR

# %% [markdown]
# ### International Bond ETFs

# %%
etf_vanguard_intl_bonds = etf_vanguard.iloc[33:36]

# %%
etf_vanguard_intl_bonds.reset_index(inplace=True, drop=True)

# %%
etf_vanguard_intl_bonds
# Out:
#                                    Name Ticker
# 0                  Total World Bond ETF   BNDW
# 1          Total International Bond ETF   BNDX
# 2  Emerging Markets Government Bond ETF   VWOB

# %% [markdown]
# ### International Stock ETFs

# %%
etf_vanguard_intl_stocks = etf_vanguard.iloc[36:48]

# %%
etf_vanguard_intl_stocks.reset_index(inplace=True, drop=True)

# %%
etf_vanguard_intl_stocks
# Out:
#                                        Name Ticker
# 0                     Total World Stock ETF     VT
# 1               ESG International Stock ETF   VSGX
# 2                  FTSE All-World ex-US ETF    VEU
# 3        FTSE All-World ex-US Small-Cap ETF    VSS
# 4                FTSE Developed Markets ETF    VEA
# 5                           FTSE Europe ETF    VGK
# 6                          FTSE Pacific ETF    VPL
# 7            Global ex-U.S. Real Estate ETF   VNQI
# 8   International Dividend Appreciation ETF   VIGI
# 9     International High Dividend Yield ETF   VYMI
# 10            Total International Stock ETF   VXUS
# 11                FTSE Emerging Markets ETF    VWO

# %% [markdown]
# ### Sector ETFs

# %%
etf_vanguard_sectors = etf_vanguard.iloc[48:]

# %%
etf_vanguard_sectors.reset_index(inplace=True, drop=True)

# %%
etf_vanguard_sectors
# Out:
#                           Name Ticker
# 0   Communication Services ETF    VOX
# 1   Consumer Discretionary ETF    VCR
# 2         Consumer Staples ETF    VDC
# 3                   Energy ETF    VDE
# 4               Financials ETF    VFH
# 5              Health Care ETF    VHT
# 6              Industrials ETF    VIS
# 7   Information Technology ETF    VGT
# 8                Materials ETF    VAW
# 9              Real Estate ETF    VNQ
# 10               Utilities ETF    VPU

# %% [markdown]
# ## Source Vanguard ETFs Historical OHLCV Data

# %% [markdown]
# ### US Bond ETFs

# %% [markdown]
# ### US Stock ETFs

# %% [markdown]
# ### International Bond ETFs

# %% [markdown]
# ### International Stock ETFs

# %% [markdown]
# ### Sector ETFs
